# %% [markdown]
# # Obstacle Detection in Static and Dynamic Environments
#
# Name: Abdul Basit Bhat
# Roll No: 102003121
# Group: 2CO5
# Date: 17-05-2022    05:53 PM

# %% [markdown]
# # Project Title: Obstacle Detection in Static and Dynamic Environments
#
# Project Type: AI Agent
#
# Project Description:
# The project is based on the idea of mapping the dataset generated by a Dynamic Environment and its respective Initial State static environment. A simulator is run for both environments. It is found that by mapping the 2 dataset generated about the obstacle positions in each case, we can make a plot and hence predict the dynamic obstacle positions in any input case.
# After the mapping of an environment by providing it with the data as a video. We can convert it into a binary data representation. Then we simulate our agent in a static case(in initial frame of video) and then in dynamic case(actual video, in which obstacles are moving). While simulation a dataset is generated for both cases about the respective obstacle positions.
# We can plot, interpolate or give the data to a Machine Learning Algorithm. Any of these methods can be used to predict the postion of obstacles in dynamic environment, provided we input only the initial static state data.
#
# Made By: Abdul Basit Bhat
# Roll No: 102003121
# Group:   2CO5

# %% [markdown]
# Note:
# The visual simulation is displayed only in first 2 Code. First 2 codes are only for demonstration. The actual data sets are
# generated by next 2 codes.

# %%
'''Static Environment. Implementation on smaller dataset'''
import os
import time
import pandas as pd
from IPython.display import clear_output
count = 1

'''These 2 Arrays represent our path'''
arr1 = [' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ',
        ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ','|']
arr2 = [' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ','|']
pos = 0
obs=0
obs1=[]
obs2=[]

def move(count):
    if count == 1:
        arr1[pos + 1] = '>'

        arr1[pos] = ' '
        '''arr1[0]=' ' '''
    else:
        arr2[pos + 1] = '>'
        arr2[pos] = ' '


def nextSafe(count):
    if count == 1:
        if arr1[pos + 1] == ' ':
            return 1
        else:
            obs1.append(pos+1)
            return 0

    if count == 2:
        if arr2[pos + 1] == ' ':
            return 1
        else:
            obs2.append(pos+1)
            return 0

def swap(count):
    if count == 1 and pos<len(arr1):
        if (arr2[pos] == 'o'):
            print('Blocked')
            print('Can do nothing, breking obstacle==--> OH NO I Scratcheddd my car')
            time.sleep(0.2)
        arr2[pos] = '>'
        arr1[pos] = ' '


    elif count == 2 and pos < len(arr2):
        if (arr1[pos] == 'o'):
            print('Blocked')
            print('Can do nothing, breking obstacle==--> OH NO I Scratcheddd my car')
            time.sleep(0.3)
        arr1[pos] = '>'
        arr2[pos] = ' '


def printt():
    print('---------------------------------------------------------------------------------------------------------------------------------')
    for i in range(1, len(arr1)):
        print(arr1[i],end='')
    print('')
    for j in range(1, len(arr2)):
        print(arr2[j],end='')
    print('')
    print('---------------------------------------------------------------------------------------------------------------------------------')
    print('\n')
    time.sleep(0.1)


'''Move forward if no obstacle'''
'''Swap path if obstacle in front'''
'''If new path has obstacle at that pos we break it'''
while(arr1[pos+1]!='|' and arr2[pos+1]!='|'):
    if (nextSafe(count) == 1):
        move(count)
        pos = pos + 1
        printt()
    else:
        swap(count)
        if (count == 1):
            count = 2
        else:
            count = 1
        printt()
    clear_output(wait=True)
print("Obstacles in Path one are at")
print(obs1)
print("Obstacles in Path two are at")
print(obs2)
# Out:
# Obstacles in Path one are at
# [4, 12, 20, 37, 46, 54, 83]
# Obstacles in Path two are at
# [5, 13, 33, 39, 47, 67, 84]

# %%
'''Dynamic Environment. Implementation on smaller dataset. Same path as above'''
import os
import time
import pandas as pd
from IPython.display import clear_output
count = 1
arr1 = [' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ',
        ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ','|']
arr2 = [' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ','|']
pos = 0
obs=0
obs1=[]
obs2=[]
def move(count):
    if count == 1:
        arr1[pos + 1] = '>'
        arr1[pos] = ' '
        arr1[pos-1]=' '
        '''arr1[0]=' '''
    else:
        arr2[pos + 1] = '>'
        arr2[pos] = ' '
        arr2[pos - 1] = ' '


def nextSafe(count):
    '''and pos+1<len(arr1)'''
    if count == 1 and pos+2<len(arr1):
        if arr1[pos + 1] == ' ' and arr1[pos + 2] == ' ':
            return 1
        else:
            obs1.append(pos+1)
            return 0
    '''and pos+1<len(arr2)'''
    if count == 2 and pos+2<len(arr2):
        if arr2[pos + 1] == ' ' and arr2[pos + 2] == ' ' :
            return 1
        else:
            obs2.append(pos+1)
            return 0

def swap(count):
    if count == 1 and pos<len(arr1):
        if (arr2[pos] == 'o'):
            print('Blocked')
            print('Can do nothing, breking obstacle==--> OH NO I Scratcheddd my car')
            time.sleep(0.2)
        arr2[pos] = '>'
        arr1[pos-1]=' '
        arr1[pos-1]=' '
    elif count == 2 and pos<len(arr2):
        if (arr1[pos] == 'o'):
            print('Blocked')
            print('Can do nothing, breking obstacle==--> OH NO I Scratcheddd my car')
            time.sleep(0.5)
        arr1[pos] = '>'
        arr2[pos] = ' '
        arr2[pos-1]=' '


def printt():
    print('-------------------------------------------')
    for i in range(1, len(arr1)):
        print(arr1[i],end='')
    print('')
    for j in range(1, len(arr2)):
        print(arr2[j],end='')
    print('')
    print('-------------------------------------------')
    print('\r')
    print('\r')
    time.sleep(0.1)

'''Same as machine learning code but here we just swap path directly'''
'''Move forward if no obstacle'''
'''Swap path if obstacle in front'''
'''If new path has obstacle at that pos we break it'''
while(arr1[pos+1]!='|' and arr2[pos+1]!='|'):

    if (arr1 != []):
        arr1.pop(0)
    if (arr2 != []):
        arr2.pop(0)

    if (nextSafe(count) == 1):
        move(count)
        pos = pos + 1
        printt()
    else:
        swap(count)

        if (count == 1):

            count = 2
        else:
            count = 1
        printt()
    clear_output(wait=True)    

print("Obstacles in Path one are at")
print(obs1)
print("Obstacles in Path two are at")
print(obs2)
# Out:
# Obstacles in Path one are at
# [2, 5, 8, 15, 19, 22, 35]
# Obstacles in Path two are at
# [2, 5, 14, 16, 19, 28, 35]

# %%
'''Static Environment. Implementation on larger dataset, The visuals may distort here'''
import os
import time
import pandas as pd
count = 1
arr1 = [' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ',
        ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ',
        'o', ' ', ' ', ' ', 'o', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ',
        ' ', 'o', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', 'o',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ',
        ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ',
        'o', ' ', ' ', ' ', 'o', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ',
        ' ', 'o', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', 'o',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', '|']
arr2 = [' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ',
        ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', 'o', ' ', ' ', ' ', 'o', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o',
        ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ',
        ' ', 'o', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ',
        ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ',
        ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', 'o', ' ', ' ', ' ', 'o', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o',
        ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ',
        ' ', 'o', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ',
        ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ','|']
pos = 0
obs=0
obs1=[]
obs2=[]
def move(count):
    if count == 1:
        arr1[pos + 1] = '>'

        arr1[pos] = ' '
    else:
        arr2[pos + 1] = '>'
        arr2[pos] = ' '


def nextSafe(count):
    if count == 1:
        if arr1[pos + 1] == ' ':
            return 1
        else:
            obs1.append(pos+1)
            return 0

    if count == 2:
        if arr2[pos + 1] == ' ':
            return 1
        else:
            obs2.append(pos+1)
            return 0

def swap(count):
    if count == 1 and pos<len(arr1):
        if (arr2[pos] == 'o'):
            '''print('Blocked')
            print('Can do nothing, breking obstacle==--> OH NO I Scratcheddd my car')'''
            '''time.sleep(0.5)'''
        arr2[pos] = '>'
        arr1[pos] = ' '


    elif count == 2 and pos < len(arr2):
        if (arr1[pos] == 'o'):
            '''print('Blocked')
            print('Can do nothing, breking obstacle==--> OH NO I Scratcheddd my car')'''
            time.sleep(0.3)
        arr1[pos] = '>'
        arr2[pos] = ' '


def printt():
    print('---------------------------------------------------------------------------------------------------------------------------------')
    for i in range(1, len(arr1)):
        print(arr1[i],end='')
    print('')
    for j in range(1, len(arr2)):
        print(arr2[j],end='')
    print('')
    '''print('-------------------------------------------')'''
    print('---------------------------------------------------------------------------------------------------------------------------------')
    print('\n')
    
    '''time.sleep(0.4)'''


'''Same as machine learning code but here we just swap path directly'''
'''Move forward if no obstacle'''
'''Swap path if obstacle in front'''
'''If new path has obstacle at that pos we break it'''
while(arr1[pos+1]!='|' and arr2[pos+1]!='|'):
    if (nextSafe(count) == 1):
        move(count)
        pos = pos + 1
        '''printt()'''
    else:
        swap(count)
        if (count == 1):
            count = 2
        else:
            count = 1
        '''printt()'''

'''print("I escaped but on the way i destroyed a lot of obstacles")'''
print('Path 1 Obstacle Positions')
print(obs1)
print('Path 2 Obstacle Positions')
print(obs2)
# Out:
# Path 1 Obstacle Positions
# [4, 12, 20, 37, 46, 54, 83, 93, 97, 108, 113, 117, 126, 135, 145, 151, 159, 164, 174, 188, 199, 210, 228, 235, 247, 256, 277, 285, 302, 311, 319, 348, 358, 362, 373, 378, 382, 391, 400, 410, 416, 424, 429, 439, 453, 464, 475, 493, 500, 512, 521]
# Path 2 Obstacle Positions
# [5, 13, 33, 39, 47, 67, 84, 95, 101, 110, 114, 118, 132, 139, 147, 154, 161, 168, 180, 192, 201, 213, 230, 238, 255, 270, 278, 298, 304, 312, 332, 349, 360, 366, 375, 379, 383, 397, 404, 412, 419, 426, 433, 445, 457, 466, 478, 495, 503, 520]

# %%
'''Dynamic Environment . Implementation on larger dataset, The visuals may distort here'''
import os
import time
import pandas as pd
count = 1
arr1 = [' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ',
        ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ',
        'o', ' ', ' ', ' ', 'o', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ',
        ' ', 'o', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', 'o',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ',
        ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ',
        'o', ' ', ' ', ' ', 'o', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ',
        ' ', 'o', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', 'o',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', '|']
arr2 = [' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ',
        ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', 'o', ' ', ' ', ' ', 'o', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o',
        ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ',
        ' ', 'o', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ',
        ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ',
        ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', 'o', ' ', ' ', ' ', 'o', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o',
        ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ',
        ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ',
        ' ', 'o', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ',
        ' ', ' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ','|']
pos = 0
obs=0
obs1=[]
obs2=[]
def move(count):
    if count == 1:
        arr1[pos + 1] = '>'
        arr1[pos] = ' '
        arr1[pos-1]=' '
        '''arr1[0]=' '''
    else:
        arr2[pos + 1] = '>'
        arr2[pos] = ' '
        arr2[pos - 1] = ' '


def nextSafe(count):
    if count == 1 and pos+2<len(arr1):
        if arr1[pos + 1] == ' ' and arr1[pos + 2] == ' ':
            return 1
        else:
            obs1.append(pos+1)
            return 0
    if count == 2 and pos+2<len(arr2):
        if arr2[pos + 1] == ' ' and arr2[pos + 2] == ' ' :
            return 1
        else:
            obs2.append(pos+1)
            return 0

def swap(count):
    if count == 1 and pos<len(arr1):
        if (arr2[pos] == 'o'):
            '''print('Blocked')
            print('Can do nothing, breking obstacle==--> OH NO I Scratcheddd my car')'''
            '''time.sleep(0.5)'''
        arr2[pos] = '>'
        arr1[pos-1]=' '
        arr1[pos-1]=' '
    elif count == 2 and pos<len(arr2):
        if (arr1[pos] == 'o'):
            '''print('Blocked')
            print('Can do nothing, breking obstacle==--> OH NO I Scratcheddd my car')'''
            '''time.sleep(0.5)'''
        arr1[pos] = '>'
        arr2[pos] = ' '
        arr2[pos-1]=' '


def printt():
    print('-------------------------------------------')
    for i in range(1, len(arr1)):
        print(arr1[i],end='')
    print('')
    for j in range(1, len(arr2)):
        print(arr2[j],end='')
    print('')
    print('-------------------------------------------')
    print('\r')
    print('\r')
    print('\r')
    print('\r')
    '''time.sleep(0.4)'''

'''Same as machine learning code but here we just swap path directly'''
'''Move forward if no obstacle'''
'''Swap path if obstacle in front'''
'''If new path has obstacle at that pos we break it'''
while(arr1[pos+1]!='|' and arr2[pos+1]!='|'):

    if (arr1 != []):
        arr1.pop(0)
    if (arr2 != []):
        arr2.pop(0)

    if (nextSafe(count) == 1):
        move(count)
        pos = pos + 1
        '''printt()'''
    else:
        swap(count)

        if (count == 1):

            count = 2
        else:
            count = 1
        '''printt()'''

'''print("I escaped but on the way i destroyed a lot of obstacles")'''
print('Path 1 Obstacle Positions')
print(obs1)
print('Path 2 Obstacle Positions')
print(obs2)
# Out:
# Path 1 Obstacle Positions
# [2, 5, 8, 15, 19, 22, 35, 39, 40, 45, 46, 47, 51, 54, 58, 60, 63, 65, 69, 75, 79, 84, 92, 94, 99, 103, 112, 115, 123, 126, 129, 143, 147, 148, 152, 154, 155, 158, 162, 166, 168, 171, 172, 176, 182, 187, 191, 199, 202, 207, 210]
# Path 2 Obstacle Positions
# [2, 5, 14, 16, 19, 28, 35, 40, 42, 45, 46, 47, 53, 56, 59, 61, 64, 66, 71, 76, 80, 85, 92, 95, 103, 109, 112, 121, 123, 126, 135, 143, 147, 149, 153, 154, 155, 161, 163, 166, 169, 171, 174, 179, 184, 187, 192, 200, 203, 210, 214]

# %%
'''Making Dataset'''
import pandas as pd

obs1=[4, 12, 20, 37, 46, 54, 83, 93, 97, 108, 113, 117, 126, 135, 145, 151, 159, 164, 174, 188, 199, 210, 228, 235, 247, 256, 277, 285, 302, 311, 319, 348, 358, 362, 373, 378, 382, 391, 400, 410, 416, 424, 429, 439, 453, 464, 475, 493, 500, 512]
obs2=[5, 13, 33, 39, 47, 67, 84, 95, 101, 110, 114, 118, 132, 139, 147, 154, 161, 168, 180, 192, 201, 213, 230, 238, 255, 270, 278, 298, 304, 312, 332, 349, 360, 366, 375, 379, 383, 397, 404, 412, 419, 426, 433, 445, 457, 466, 478, 495, 503, 520]

obs1D=[2, 5, 8, 15, 19, 22, 35, 39, 40, 45, 46, 47, 51, 54, 58, 60, 63, 65, 69, 75, 79, 84, 92, 94, 99, 103, 112, 115, 123, 126, 129, 143, 147, 148, 152, 154, 155, 158, 162, 166, 168, 171, 172, 176, 182, 187, 191, 199, 202, 207]
obs2D=[2, 5, 14, 16, 19, 28, 35, 40, 42, 45, 46, 47, 53, 56, 59, 61, 64, 66, 71, 76, 80, 85, 92, 95, 103, 109, 112, 121, 123, 126, 135, 143, 147, 149, 153, 154, 155, 161, 163, 166, 169, 171, 174, 179, 184, 187, 192, 200, 203, 210]

'''df=pd.DataFrame([[obs1],[obs1D]],[[obs2],[obs2D]])'''
df=pd.DataFrame({'OBS1':obs1,'OBS1D':obs1D})
df.to_csv("StaticDinamicDataSetLane1.csv")
print(df)

df2=pd.DataFrame({'OBS2':obs2,'OBS2D':obs2D})
df2.to_csv("StaticDinamicDataSetLane2.csv")
print(df2)
# Out:
#     OBS1  OBS1D
# 0      4      2
# 1     12      5
# 2     20      8
# 3     37     15
# 4     46     19
# 5     54     22
# 6     83     35
# 7     93     39
# 8     97     40
# 9    108     45
# 10   113     46
# 11   117     47
# 12   126     51
# 13   135     54
# 14   145     58
# 15   151     60
# 16   159     63
# 17   164     65
# 18   174     69
# 19   188     75
# 20   199     79
# 21   210     84
# 22   228     92
# 23   235     94
# 24   247     99
# 25   256    103
# 26   277    112
# 27   285    115
# 28   302    123
# 29   311    126
# 30   319    129
# 31   348    143
# 32   358    147
# 33   362    148
# 34   373    152
# 35   378    154
# 36   382    155
# 37   391    158
# 38   400    162
# 39   410    166
# 40   416    168
# 41   424    171
# 42   429    172
# 43   439    176
# 44   453    182
# 45   464    187
# 46   475    191
# 47   493    199
# 48   500    202
# 49   512    207
#     OBS2  OBS2D
# 0      5      2
# 1     13      5
# 2     33     14
# ...

# %% [markdown]
# 	OBS1	OBS1D	OBS2	OBS2D
# 0	4	2	5	2
# 1	12	5	13	5
# 2	20	8	33	14
# 3	37	15	39	16
# 4	46	19	47	19
# 5	54	22	67	28
# 6	83	35	84	35
# 7	93	39	95	40
# 8	97	40	101	42
# 9	108	45	110	45
# 10	113	46	114	46
# 11	117	47	118	47
# 12	126	51	132	53
# 13	135	54	139	56
# 14	145	58	147	59
# 15	151	60	154	61
# 16	159	63	161	64
# 17	164	65	168	66
# 18	174	69	180	71
# 19	188	75	192	76
# 20	199	79	201	80
# 21	210	84	213	85
# 22	228	92	230	92
# 23	235	94	238	95
# 24	247	99	255	103
# 25	256	103	270	109
# 26	277	112	278	112
# 27	285	115	298	121
# 28	302	123	304	123
# 29	311	126	312	126
# 30	319	129	332	135
# 31	348	143	349	143
# 32	358	147	360	147
# 33	362	148	366	149
# 34	373	152	375	153
# 35	378	154	379	154
# 36	382	155	383	155
# 37	391	158	397	161
# 38	400	162	404	163
# 39	410	166	412	166
# 40	416	168	419	169
# 41	424	171	426	171
# 42	429	172	433	174
# 43	439	176	445	179
# 44	453	182	457	184
# 45	464	187	466	187
# 46	475	191	478	192
# 47	493	199	495	200
# 48	500	202	503	203
# 49	512	207	520	210
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# '''From the 2 graphs we can get a full list of static to dynamic mapping. Thus if we know initial position of an obstacle
# then we can derive its dynamic position provided we set the same speed of simulator object in both static and dynamic case.
# i.e if in our simulator the static obstacle is obtained at a position named pos 1 if speed of our device was v. If we move the
# device in dynamic environment we will find the same obstacle at a position given by the graph we plotted above.
#
# Steps:
# If we get a lot of dataset about a particular environment, we can probably make a robust algorithm for that environment.
# The we just have to take pic of the initial state and then pass it to algorithm.
# We can train our model by providing it with videos of an environment. The first frame of each environmrnt will behave as input data
# and the rset of the data will behave as output (at a particular time).We get a dataset with obstacle position at each time.
# at t=0 whatever the pos, it will be input and the rest of posetions at respective times will be output.
# The algorithm will output the speed and dynamic positions of obstacles the drone will face in its path. This will be done
# beforehand by the algorithm and we get a static dataset for dynamic positions also of obstacle the drone will face if it moves at
# speed given by algorithm. Means that we get a dataset that predicts the pos of the obstacle the drone will face at that time.
#
# '''

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# '''We obsereved that in 2 different paths with different obstacle position but with in dynamic conditions(moving forward)
# will produce almost similar graphs. By this we conclude that extent of dynamic nature does not depend on initial obs positions,
# but it only depends on dynamic movements.
# We can get these dynamic conditions by creating a graph bw obs pos in static initial case and dynamic encountering case,
# then by maths we can posibly derive an equation that can get us present obstacle position by inputing the obs pos as in
# static image.Here i can easily get a mapping for every static obs position and its dynamic pos but in complex environments
# I need ML algorithms to do the job.'''

# %% [markdown]
# '''Path Finding
#
# 1.Made a simple agent that can detect obstacles and swap bw paths.
# 2.Added feature to record obstacle positions.
# 3.Made the path obstacles dynamic by moving them forward in separate code.
# 4.Added feature to record obstacle positions in dynamic path.
# 5.Made a mapping between static and dynamic pos of obstacle.
# 6.Made a graph where I can directly get the dynamic pos by simply inputing initial state obstacle pos of the environ.
#
# Insights:
# 1.Obstacle Position is immaterial in dynamic nature measurement. It is the relative change from the static (initial) and
#   dynamic position which matters.
# 2.If the dynamic environment is same then no matter the pos of obstacle, the mapping will be same.
# 3.If we have a pic of initial state and hence static obstacle positions, we can easily predefine path by making a list
#   of output from the graph for our static pos inputs.
# 4.By using this our agent will know it before time the real time position of obstacle and can dodge it blindly.
#
# Note:
# This was a basic example. It works just for my created simple dynamic environment. It was just for illustration.
# However the principles remain the same. The environ and data set may be totally different. I could have taken only
# one path as well. The graph may be anything, any geometrical shape.
# In real life.
# 1.We get videos of dynamic environments.
# 2.Get the first pic of a video and convert its info to binary knowledge representation. We can use it as static environ.
#   In this we can simulate our agent and find static pos.
# 3.Now we can convert the rest of the video into binary and simulate our agent in it. By this we will get a dynamic dataset.
# 4.Now by repeating this with a lot of dataset we can plot and merge the graphs between static and dynamic dataset
#   and hence get a final graph. This graph may not be perfect but a near perfect mapping. We can use this mapping for
#   detecting pos of realtime obstacles when we are given the initial positions data.
# 5.We can also use interpolation to get position of obstacles not encountered on the path.
# 6.It is assumed that speed of our drone in both environments is same.
# '''

# %% [markdown]
# If images are not available please refer the following link for images and xls file
# https://drive.google.com/drive/folders/1ffxnyUy-tn93pvswiRisSjQF94PtVuPd?usp=sharing
